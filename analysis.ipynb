# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_stages = 6

x = np.arange(0, 500)

fig = plt.figure()
ax = fig.add_subplot()
mean_delta = 100
sigma = mean_delta / 3
for k in range(n_stages):
    y = np.exp(-0.5*((x - mean_delta * k) / sigma)**2)
    ax.plot(x, y)
